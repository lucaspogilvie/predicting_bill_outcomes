# %%
import pandas as pd
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %%
colors = sns.color_palette("Set1")
colors
# Out:
# [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
#  (0.596078431372549, 0.3058823529411765, 0.6392156862745098),
#  (1.0, 0.4980392156862745, 0.0),
#  (1.0, 1.0, 0.2),
#  (0.6509803921568628, 0.33725490196078434, 0.1568627450980392),
#  (0.9686274509803922, 0.5058823529411764, 0.7490196078431373),
#  (0.6, 0.6, 0.6)]

# %%
colors = px.colors.qualitative.Set1

# %%
tab20b = sns.color_palette("tab20b")
tab20c = sns.color_palette("tab20c")
tab20b
# Out:
# [(0.2235294117647059, 0.23137254901960785, 0.4745098039215686),
#  (0.3215686274509804, 0.32941176470588235, 0.6392156862745098),
#  (0.4196078431372549, 0.43137254901960786, 0.8117647058823529),
#  (0.611764705882353, 0.6196078431372549, 0.8705882352941177),
#  (0.38823529411764707, 0.4745098039215686, 0.2235294117647059),
#  (0.5490196078431373, 0.6352941176470588, 0.3215686274509804),
#  (0.7098039215686275, 0.8117647058823529, 0.4196078431372549),
#  (0.807843137254902, 0.8588235294117647, 0.611764705882353),
#  (0.5490196078431373, 0.42745098039215684, 0.19215686274509805),
#  (0.7411764705882353, 0.6196078431372549, 0.2235294117647059),
#  (0.9058823529411765, 0.7294117647058823, 0.3215686274509804),
#  (0.9058823529411765, 0.796078431372549, 0.5803921568627451),
#  (0.5176470588235295, 0.23529411764705882, 0.2235294117647059),
#  (0.6784313725490196, 0.28627450980392155, 0.2901960784313726),
#  (0.8392156862745098, 0.3803921568627451, 0.4196078431372549),
# ...

# %%
tab20c
# Out:
# [(0.19215686274509805, 0.5098039215686274, 0.7411764705882353),
#  (0.4196078431372549, 0.6823529411764706, 0.8392156862745098),
#  (0.6196078431372549, 0.792156862745098, 0.8823529411764706),
#  (0.7764705882352941, 0.8588235294117647, 0.9372549019607843),
#  (0.9019607843137255, 0.3333333333333333, 0.050980392156862744),
#  (0.9921568627450981, 0.5529411764705883, 0.23529411764705882),
#  (0.9921568627450981, 0.6823529411764706, 0.4196078431372549),
#  (0.9921568627450981, 0.8156862745098039, 0.6352941176470588),
#  (0.19215686274509805, 0.6392156862745098, 0.32941176470588235),
#  (0.4549019607843137, 0.7686274509803922, 0.4627450980392157),
#  (0.6313725490196078, 0.8509803921568627, 0.6078431372549019),
#  (0.7803921568627451, 0.9137254901960784, 0.7529411764705882),
#  (0.4588235294117647, 0.4196078431372549, 0.6941176470588235),
#  (0.6196078431372549, 0.6039215686274509, 0.7843137254901961),
#  (0.7372549019607844, 0.7411764705882353, 0.8627450980392157),
# ...

# %% [markdown]
# # Read In data

# %%
df = pd.read_csv('../../Data/Merged_Data/cleaned_data.csv.zip')
df_with_sponsors = pd.read_csv('../../Data/Merged_Data/cleaned_data_with_sponsors.csv.zip')

states_2017 = pd.read_csv('../../Data/Legislative_Control_Data/legis_control_2017.csv')
states_2018 = pd.read_csv('../../Data/Legislative_Control_Data/legis_control_2018.csv')

# %% [markdown]
# # Imbalanced Data

# %%
#plot
plt.figure(figsize = (10,7))
fig = sns.countplot(data = df, x = 'law_enacted', palette = [tab20b[0], tab20c[8]])
fig.set_xticklabels(['Law Failed', 'Law Enacted'])
fig.bar_label(fig.containers[0], labels = ['79.6%','20.4%'])
plt.title('Frequency of Laws being Enacted')
plt.xlabel('')
plt.ylabel('Count')

plt.savefig(f'Imbalanced.png');

# %% [markdown]
# # Passing Each Chamber Frequency

# %%
print(df['pass_1st_chamber'].value_counts(normalize = True)[1])
print(df['pass_2nd_chamber'].value_counts(normalize = True)[1])
print(df['law_enacted'].value_counts(normalize = True)[1])
# Out:
# 0.31014706293771505
# 0.24043904395102253
# 0.2036779722660002

# %%
#plot
plt.figure(figsize = (10,7))
fig = sns.barplot(x = ['Passed First Chamber', ' Passed Second Chamber', 'Law Enacted'], y = [31.014706293771505,24.043904395102253,20.36779722660002], palette = [tab20c[0], tab20c[1], tab20c[2]])
fig.bar_label(fig.containers[0], labels = ['31%','24%', '20%'])
fig.set_yticklabels(['0%', '10%', '20%' ,'30%' ,'40%' ,'50%'])
plt.title('Frequency of Laws Passing to the Next Stage')
plt.xlabel('')
plt.ylabel('Percent of Laws Passed')
plt.ylim((0,50))

plt.savefig(f'chamber_to_chamber_pass_rate.png');
# Out:
# /var/folders/2s/0cx_vgq111qdb9jklnsjxt5w0000gp/T/ipykernel_886/3441469803.py:5: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ## Passing each chamber given it passed the last one

# %%
print(df['pass_1st_chamber'].value_counts(normalize = True)[1])
print(df[df['pass_1st_chamber'] == 1]['pass_2nd_chamber'].value_counts(normalize = True)[1])
print(df[df['pass_2nd_chamber'] == 1]['law_enacted'].value_counts(normalize = True)[1])
# Out:
# 0.31014706293771505
# 0.74718864634073
# 0.8461001435054105

# %%
#plot
plt.figure(figsize = (10,7))
fig = sns.barplot(
    x = ['Passed First Chamber',
         '''Passed Second Chamber Given 
It Passed the First''', 
         '''Law Enacted Given it Passed 
the Second Chamber'''], \
                  y = [31.014706293771505,74.718864634073, 84.61001435054105], palette = [tab20c[0], tab20c[1], tab20c[2]])
fig.bar_label(fig.containers[0], labels = ['31.0%','74.7%', '84.6%'])
fig.set_yticklabels(['0%', '20%', '40%' ,'60%' ,'80%' ,'100%'])
plt.title('Frequency of Laws Passing to the Next Stage')
plt.xlabel('')
plt.ylabel('Percent of Laws Passed')
plt.ylim((0,100))

plt.savefig(f'given_passed_prior_chamber_pass_rate.png');
# Out:
# /var/folders/2s/0cx_vgq111qdb9jklnsjxt5w0000gp/T/ipykernel_886/1824605854.py:11: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# # State Party Control Map

# %%
#Dictionary that converts sate names to abbreviations , needed to use plotly graph
us_state_to_abbrev = {"Alabama": "AL", "Alaska": "AK", "Arizona": "AZ", "Arkansas": "AR", "California": "CA",
    "Colorado": "CO", "Connecticut": "CT", "Delaware": "DE", "Florida": "FL", "Georgia": "GA", "Hawaii": "HI",
    "Idaho": "ID", "Illinois": "IL", "Indiana": "IN", "Iowa": "IA", "Kansas": "KS", "Kentucky": "KY", "Louisiana": "LA",
    "Maine": "ME", "Maryland": "MD", "Massachusetts": "MA", "Michigan": "MI", "Minnesota": "MN", "Mississippi ": "MS",
    "Missouri": "MO", "Montana": "MT", "Nebraska": "NE", "Nevada": "NV", "New Hampshire": "NH", "New Jersey": "NJ", "New Mexico": "NM",
    "New York": "NY","North Carolina": "NC","North Dakota  ": "ND","Ohio": "OH","Oklahoma": "OK", "Oregon": "OR",
    "Pennsylvania": "PA", "Rhode Island ": "RI", "South Carolina": "SC", "South Dakota": "SD", "Tennessee": "TN", "Texas": "TX", "Utah": "UT", 
    "Vermont": "VT", "Virginia": "VA", "Washington": "WA", "West Virginia": "WV", "Wisconsin": "WI", "Wyoming": "WY", 
    "District of Columbia": "DC", "American Samoa": "AS", "Guam": "GU", "Northern Mariana Islands": "MP", "Puerto Rico": "PR", 
    "United States Minor Outlying Islands": "UM", "U.S. Virgin Islands": "VI"
}

states_2017.states = states_2017.states.map(us_state_to_abbrev)
states_2018.states = states_2018.states.map(us_state_to_abbrev)

# %%
#Make column showing difference between Democrats and Republicans. 
#This will then be used to show the party in control
states_2017['senate_party_diff'] = states_2017['senate_dem'] - states_2017['senate_rep']
states_2017['house_party_diff'] = states_2017['house_dem'] - states_2017['house_rep']
#Do the same for 2018
states_2018['senate_party_diff'] = states_2018['senate_dem'] - states_2018['senate_rep']
states_2018['house_party_diff'] = states_2018['house_dem'] - states_2018['house_rep']


#Make the column showing the majority party for the senat and house for each state on the given year
states_2017['senate_party'] = states_2017['senate_party_diff'].map(lambda x: 'Rep' if x < 0 else 'Dem' if x > 0 else 'Split')
states_2017['house_party'] = states_2017['house_party_diff'].map(lambda x: 'Rep' if x < 0 else 'Dem' if x > 0 else 'Split')
#do same for smaller dataset
states_2018['senate_party'] = states_2018['senate_party_diff'].map(lambda x: 'Rep' if x < 0 else 'Dem' if x > 0 else 'Split')
states_2018['house_party'] = states_2018['house_party_diff'].map(lambda x: 'Rep' if x < 0 else 'Dem' if x > 0 else 'Split')

# %%
score_dict = {'Rep':1, 'Dem':-1, 'Ind':0, 'Split':0}
states_2017['state_party_control_score'] = states_2017.senate_party.map(score_dict) + states_2017.house_party.map(score_dict) + states_2017.gov_party.map(score_dict)
states_2018['state_party_control_score'] = states_2018.senate_party.map(score_dict) + states_2018.house_party.map(score_dict) + states_2018.gov_party.map(score_dict)

# %%
#Plotly function to make Geography graphs! Very cool
fig = px.choropleth(states_2017, #DataFrame
                    locations="states", #Abbreviated State Column
                    locationmode = 'USA-states', #Plotly's set location mode to usa states
                    color= "state_party_control_score", #Color based off of frequency
                    color_continuous_scale= [colors[1],colors[0]], #Color scale from low to high frequency, Blue is low
                    scope = 'usa', #Only want to see the US
                    width = 1000, #Size of graph
                    height = 500, #Size of graph
                    )

fig.update_layout(title_text='State Party Control 2017', title_x=0.45, #Center Title
                 margin={"r":15,"t":50,"l":15,"b":20}, #Change the margins
                 coloraxis_colorbar=dict(
                     title="Party Contorl",
                     tickvals=[-2.8,0,2.8],
                     ticktext=["Democrat",'Split', "Republican"],
                     dtick=2) #Change the Legen Format
                 )

#Add State labels
fig.add_scattergeo(
    locations= states_2017['states'],
    locationmode= "USA-states",
    text = states_2017['states'],
    mode = 'text',
    textfont=dict(
            size=8,
            
    ))
fig.show()

# %%
#Save Graph
fig.write_image(f'state_party_control_2017.png')

# %%
#Plotly function to make Geography graphs! Very cool
fig = px.choropleth(states_2018, #DataFrame
                    locations="states", #Abbreviated State Column
                    locationmode = 'USA-states', #Plotly's set location mode to usa states
                    color="state_party_control_score", #Color based off of frequency
                    color_continuous_scale= [colors[1],colors[0]], #Color scale from low to high frequency, Blue is low
                    scope = 'usa', #Only want to see the US
                    width = 1000, #Size of graph
                    height = 500, #Size of graph
                    )


fig.update_layout(title_text='State Party Control 2018', title_x=0.45, #Center Title
                 margin={"r":15,"t":50,"l":15,"b":20}, #Change the margins
                 coloraxis_colorbar=dict(
                     title="Party Contorl",
                     tickvals=[-2.8,0,2.8],
                     ticktext=["Democrat",'Split', "Republican"],
                     dtick=2) #Change the Legen Format
                 )

#Add State labels
fig.add_scattergeo(
    locations= states_2018['states'],
    locationmode= "USA-states",
    text = states_2018['states'],
    mode = 'text',
    textfont=dict(
            size=8,
            
    ))

fig.show()

# %%
#Save Graph
fig.write_image(f'state_party_control_2018.png')

# %% [markdown]
# # Law Pass Rate for different state Controls

# %%
#Make column showing difference between Democrats and Republicans. 
#This will then be used to show the party in control
df['senate_party_diff'] = df['senate_dem'] - df['senate_rep']
df['house_party_diff'] = df['house_dem'] - df['house_rep']
#Do the same for our smaller dataset
df_with_sponsors['senate_party_diff'] = df_with_sponsors['senate_dem'] - df_with_sponsors['senate_rep']
df_with_sponsors['house_party_diff'] = df_with_sponsors['house_dem'] - df_with_sponsors['house_rep']


#Make the column showing the majority party for the senat and house for each state on the given year
df['senate_party'] = df['senate_party_diff'].map(lambda x: 'Rep' if x < 0 else 'Dem' if x > 0 else 'Split')
df['house_party'] = df['house_party_diff'].map(lambda x: 'Rep' if x < 0 else 'Dem' if x > 0 else 'Split')
#do same for smaller dataset
df_with_sponsors['senate_party'] = df_with_sponsors['senate_party_diff'].map(lambda x: 'Rep' if x < 0 else 'Dem' if x > 0 else 'Split')
df_with_sponsors['house_party'] = df_with_sponsors['house_party_diff'].map(lambda x: 'Rep' if x < 0 else 'Dem' if x > 0 else 'Split')

#Making column that is Dem if the house, Senate and Governor are all democrats. Same for republican. And if they differ, than they are "split"
df['state_party_control'] = df.apply(lambda x: 'Dem' if (x.house_party == 'Dem' and x.senate_party == 'Dem' and x.gov_party == 'Dem') else \
         ('Rep' if (x.house_party == 'Rep' and x.senate_party == 'Rep' and x.gov_party == 'Rep') else 'Split'), axis = 1)
#Do the same for smaller dataset
df_with_sponsors['state_party_control'] = df_with_sponsors.apply(lambda x: 'Dem' if (x.house_party == 'Dem' and x.senate_party == 'Dem' and x.gov_party == 'Dem') else \
         ('Rep' if (x.house_party == 'Rep' and x.senate_party == 'Rep' and x.gov_party == 'Rep') else 'Split'), axis = 1)

# %%
df_with_sponsors.groupby(['state_party_control', 'majority_sponsor_party'])['law_enacted'].mean()
# Out:
# state_party_control  majority_sponsor_party
# Dem                  Dem                       0.281529
#                      Neither                   0.201330
#                      Rep                       0.215412
# Rep                  Dem                       0.095920
#                      Neither                   0.257763
#                      Rep                       0.323886
# Split                Dem                       0.275245
#                      Neither                   0.154892
#                      Rep                       0.260920
# Name: law_enacted, dtype: float64

# %%
colors = sns.color_palette("Set1")
colors
# Out:
# [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
#  (0.596078431372549, 0.3058823529411765, 0.6392156862745098),
#  (1.0, 0.4980392156862745, 0.0),
#  (1.0, 1.0, 0.2),
#  (0.6509803921568628, 0.33725490196078434, 0.1568627450980392),
#  (0.9686274509803922, 0.5058823529411764, 0.7490196078431373),
#  (0.6, 0.6, 0.6)]

# %%
order = ['Rep', 'Split', 'Dem']

plt.figure(figsize = (12,8))
fig = sns.barplot(data = df_with_sponsors[df_with_sponsors['majority_sponsor_party'] != 'Neither'],\
                 x = 'state_party_control', y = 'law_enacted', hue = 'majority_sponsor_party',\
                 errwidth = 0, order = order, palette = [colors[0],colors[1]])

fig.set_xticklabels(['Republican State', 'Split State', 'Democrat State'])
fig.bar_label(fig.containers[0], labels = ['32.4%','26.1%', '21.5%'])
fig.bar_label(fig.containers[1], labels = ['9.6%','27.5%', '28.2%'])

fig.set_yticklabels(['0%', '5%', '10%' ,'15%' ,'20%' ,'25%', '30%' ,'35%', '40%'])
plt.ylim(0,.4)

plt.xlabel('')
plt.ylabel('Percent of Laws Passed')

plt.legend(title = 'Party that Introduced Bill')

plt.title('Rate of bill becoming a Law for each party control by which party introduced the bill')

plt.savefig('pass_rate_for_state_control_by_who_introduced.png');
# Out:
# /var/folders/2s/0cx_vgq111qdb9jklnsjxt5w0000gp/T/ipykernel_886/2941850535.py:12: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
